# %%
import pandas as pd

# %%
celine = pd.read_csv('celine.csv', index_col = 'Year')

# %%
svet = pd.read_csv('svet.csv')

# %%
svet
# Out:
#       Domain Code Domain  Country Code  Country  Element Code         Element  \
# 0              QC  Crops             8  Albania          5312  Area harvested
# 1              QC  Crops             8  Albania          5312  Area harvested
# 2              QC  Crops             8  Albania          5312  Area harvested
# 3              QC  Crops             8  Albania          5312  Area harvested
# 4              QC  Crops             8  Albania          5312  Area harvested
# 5              QC  Crops             8  Albania          5312  Area harvested
# 6              QC  Crops             8  Albania          5312  Area harvested
# 7              QC  Crops             8  Albania          5312  Area harvested
# 8              QC  Crops             8  Albania          5312  Area harvested
# 9              QC  Crops             8  Albania          5312  Area harvested
# 10             QC  Crops             8  Albania          5312  Area harvested
# ...
