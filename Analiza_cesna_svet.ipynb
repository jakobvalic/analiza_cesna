# %%
import pandas as pd

# %%
celine = pd.read_csv('celine.csv', index_col = 'Year')

# %%
svet = pd.read_csv('svet.csv')

# %%
svet
# Out:
#       Domain Code Domain  Country Code  Country  Element Code         Element  \
# 0              QC  Crops             8  Albania          5312  Area harvested
# 1              QC  Crops             8  Albania          5312  Area harvested
# 2              QC  Crops             8  Albania          5312  Area harvested
# 3              QC  Crops             8  Albania          5312  Area harvested
# 4              QC  Crops             8  Albania          5312  Area harvested
# 5              QC  Crops             8  Albania          5312  Area harvested
# 6              QC  Crops             8  Albania          5312  Area harvested
# 7              QC  Crops             8  Albania          5312  Area harvested
# 8              QC  Crops             8  Albania          5312  Area harvested
# 9              QC  Crops             8  Albania          5312  Area harvested
# 10             QC  Crops             8  Albania          5312  Area harvested
# ...

# %%
svet['Country'][200:600];

# %%
svet[svet.Value > 10**5]
# Out:
#       Domain Code Domain  Country Code    Country  Element Code     Element  \
# 66             QC  Crops             8    Albania          5419       Yield
# 67             QC  Crops             8    Albania          5419       Yield
# 203            QC  Crops            12    Algeria          5419       Yield
# 329            QC  Crops            32  Argentina          5419       Yield
# 333            QC  Crops            32  Argentina          5419       Yield
# 334            QC  Crops            32  Argentina          5419       Yield
# 377            QC  Crops            32  Argentina          5510  Production
# 378            QC  Crops            32  Argentina          5510  Production
# 379            QC  Crops            32  Argentina          5510  Production
# 380            QC  Crops            32  Argentina          5510  Production
# 381            QC  Crops            32  Argentina          5510  Production
# ...

# %%
cesen_po_letih = svet.groupby('Year Code')

# %%
cesen_po_letih['Value'].mean()
# Out:
# Year Code
# 1964     53936.747059
# 1965     54593.900000
# 1966     56448.017647
# 1967     57734.958824
# 1968     59706.123529
# 1969     60997.200000
# 1970     51639.229412
# 1971     55496.658824
# 1972     53551.388235
# 1973     58549.235294
# 1974     58824.121387
# 1975     58619.795455
# 1976     58597.062500
# 1977     62385.761364
# 1978     64534.238636
# 1979     67617.871508
# 1980     64642.494444
# 1981     66260.623656
# 1982     70372.672043
# 1983     72810.043011
# 1984     74779.263441
# 1985     74299.801075
# 1986     76730.962366
# 1987     78924.878307
# 1988     79760.370370
# 1989     82647.529101
# 1990     82076.643564
# 1991     86194.912195
# 1992     77523.514170
# 1993     77856.644000
# 1994     78635.154150
# 1995     83191.451362
# 1996     85861.419231
# 1997     84621.615970
# 1998     86322.812030
# 1999     90140.078067
# 2000     99315.992647
# 2001    103870.878676
# 2002    112814.220588
# 2003    118280.248201
# 2004    119847.751724
# ...

# %%
svet['desetletje'] = 10 * (svet.Year // 10)

# %%
svet;

# %%
svet_po_desetletjih = svet.groupby('desetletje')

# %%
svet_po_desetletjih.size()
# Out:
# desetletje
# 1960    1242
# 1970    2106
# 1980    2208
# 1990    2725
# 2000    2934
# 2010    1200
# dtype: int64
